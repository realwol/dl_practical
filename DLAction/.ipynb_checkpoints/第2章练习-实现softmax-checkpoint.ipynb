# %% [markdown]
# # softmax实现练习
#  在本章练习中我们将逐步完成：
# * 1.熟悉使用CIFAR-10 数据集
# * 2.编码softmax_loss_naive函数 使用显式循环计算损失函数以及梯度
# * 3.编码softmax_loss_vectorized函数  使用向量化表达计算损失函数以及梯度
# * 4.编码最小批量梯度下降算法 训练softmax分类器
# * 5.使用验证数据选择超参数

# %%
#-*- coding: utf-8 -*-
import random
import numpy as np
from utils.data_utils import load_CIFAR10
from classifiers.chapter2 import *
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) 
# %load_ext autoreload
# %autoreload 2

# %%
# 导入 CIFAR-10 数据.
cifar10_dir = 'datasets/cifar-10-batches-py'
X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

# 查看数据
print '训练数据（数据个数，数据维度）: ', X_train.shape
print '训练数据标记（数据标记个数，）: ', y_train.shape
print '测试数据（数据个数，数据维度）: ', X_test.shape
print '测试数据标记（数据标记个数，）: ', y_test.shape
# Out:
# 训练数据（数据个数，数据维度）:  (50000L, 32L, 32L, 3L)
# 训练数据标记（数据标记个数，）:  (50000L,)
# 测试数据（数据个数，数据维度）:  (10000L, 32L, 32L, 3L)
# 测试数据标记（数据标记个数，）:  (10000L,)

# %%
# 数据可视化.
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
samples_per_class = 7
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(X_train[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %% [markdown]
# ## 1.数据预处理
# 在通常情况下，我们需要对输入数据进行归一化处理，也就是使得数据呈均值为零，方差为1的标准正态分布。由于图像的特征范围在[0,255]，其方差已经被约束了，我们只需要将数据进行零均值中心化处理即可，不需要将数据压缩在[-1,1]范围(当然，你也可以进行此项处理)。

# %%
def get_CIFAR10_data(num_training=49000, num_validation=100, num_test=10000, num_sample=250):
  # 导入 CIFAR-10 data
  cifar10_dir = 'datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # 采样数据
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]
  mask = np.random.choice(num_training, num_sample, replace=False)
  X_sample = X_train[mask]
  y_sample = y_train[mask]
  
  # 将数据重塑成（数据个数，维度）形状
  X_train = np.reshape(X_train, (X_train.shape[0], -1))
  X_val = np.reshape(X_val, (X_val.shape[0], -1))
  X_test = np.reshape(X_test, (X_test.shape[0], -1))
  X_sample = np.reshape(X_sample, (X_sample.shape[0], -1))
  
  # 数据预处理，减去其均值
  mean_image = np.mean(X_train, axis = 0)
  X_train -= mean_image
  X_val -= mean_image
  X_test -= mean_image
  X_sample -= mean_image
  
  #在每列数据中加入偏置项
  X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
  X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
  X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
  X_sample = np.hstack([X_sample, np.ones((X_sample.shape[0], 1))])
  
  return X_train, y_train, X_val, y_val, X_test, y_test, X_sample, y_sample

X_train, y_train, X_val, y_val, X_test, y_test, X_sample, y_sample = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
print 'sample data shape: ', X_sample.shape
print 'sample labels shape: ', y_sample.shape
# Out:
# Train data shape:  (49000L, 3073L)
# Train labels shape:  (49000L,)
# Validation data shape:  (100L, 3073L)
# Validation labels shape:  (100L,)
# Test data shape:  (10000L, 3073L)
# Test labels shape:  (10000L,)
# sample data shape:  (250L, 3073L)
# sample labels shape:  (250L,)

# %% [markdown]
# ## 2.使用显式循环计算损失函数以及梯度

# %%
#首先我们将用循环的方式实现softmax的损失函数（代价函数）
#打开 classifiers/chapter2/softmax_loss.py 文件并实现softmax_loss_naive函数
#完成之后运行该单元代码
from classifiers.chapter2.softmax_loss import softmax_loss_naive
import time

# 初始化权重
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_sample, y_sample, 0.0)

# 你的初始化损失值应该接近于 -log(0.1).
print '你实现的softmax损失值loss: %f' % loss
print '正确的损失值: %f' % ( -np.log(0.1) )
# Out:
# 你实现的softmax损失值loss: 2.399134
# 正确的损失值: 2.302585

# %%
# 使用数值梯度检验你已实现的softmax_loss_naive
# 你实现的梯度应该要接近于数值梯度
from utils.gradient_check import grad_check_sparse
loss, grad = softmax_loss_naive(W, X_sample, y_sample, 0.0)

print '检验无权重衰减的softmax_loss_naive梯度：'
f = lambda w: softmax_loss_naive(w, X_sample, y_sample, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

print '检验加入权重衰减项后的softmax_loss_naive梯度：'
loss, grad = softmax_loss_naive(W, X_sample, y_sample, 1e2)
f = lambda w: softmax_loss_naive(w, X_sample, y_sample, 1e2)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# 检验无权重衰减的softmax_loss_naive梯度：
# numerical: 1.484031 analytic: 1.484031, relative error: 8.196649e-09
# numerical: 0.089950 analytic: 0.089950, relative error: 2.417373e-07
# numerical: -0.162603 analytic: -0.162603, relative error: 1.355137e-07
# numerical: -1.719382 analytic: -1.719382, relative error: 3.607616e-08
# numerical: -1.522434 analytic: -1.522434, relative error: 1.459378e-08
# numerical: 1.979159 analytic: 1.979159, relative error: 4.577545e-08
# numerical: 1.501983 analytic: 1.501983, relative error: 6.244010e-08
# numerical: 2.684078 analytic: 2.684077, relative error: 1.508491e-08
# numerical: -0.978707 analytic: -0.978707, relative error: 1.073044e-10
# numerical: 1.400801 analytic: 1.400801, relative error: 1.668291e-08
# 检验加入权重衰减项后的softmax_loss_naive梯度：
# numerical: 1.138564 analytic: 1.138564, relative error: 1.461414e-08
# numerical: 1.751027 analytic: 1.751027, relative error: 3.351393e-08
# numerical: -3.351010 analytic: -3.351011, relative error: 1.417672e-08
# numerical: -0.596428 analytic: -0.596428, relative error: 7.473794e-09
# numerical: -1.542423 analytic: -1.542423, relative error: 1.128846e-08
# numerical: 0.348764 analytic: 0.348764, relative error: 7.893691e-08
# numerical: 1.816024 analytic: 1.816024, relative error: 1.689317e-08
# numerical: -1.587426 analytic: -1.587426, relative error: 1.848662e-08
# numerical: -7.526044 analytic: -7.526044, relative error: 4.747490e-09
# numerical: 1.267875 analytic: 1.267875, relative error: 8.783202e-09

# %% [markdown]
# ## 3. 使用向量化表达计算损失函数以及梯度

# %%
# 现在我们将实现向量化的softmax损失及其梯度计算
# 打开softmax_loss_vectorized函数并完成相应任务，运行该段代码
# 向量化版本应该和显式循环版本相同，但前者的计算效率应该快速得很多
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_sample, y_sample, 0.00001)
toc = time.time()
print '显式循环版loss: %e   花费时间 %fs' % (loss_naive, toc - tic)

from classifiers.chapter2.softmax_loss import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_sample, y_sample, 0.00001)
toc = time.time()
print '向量化版本 loss: %e    花费时间 %fs' % (loss_vectorized, toc - tic)

# 比较结果
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print '损失误差: %f' % np.abs(loss_naive - loss_vectorized)
print '梯度误差: %f' % grad_difference
# Out:
# 显式循环版loss: 2.399134e+00   花费时间 0.047000s
# 向量化版本 loss: 2.399134e+00    花费时间 0.003000s
# 损失误差: 0.000000
# 梯度误差: 0.000000

# %% [markdown]
# ## 4.最小批量梯度下降算法 训练softmax分类器

# %%
# 打开softmax.trian()完成随机梯度下降任务，然后执行该段代码
from classifiers.chapter2.softmax import *
softmax = Softmax()
tic = time.time()
loss_hist = softmax.train(X_sample, y_sample, learning_rate=1e-7, reg=5e4,
                      num_iters=3500, verbose=True)
toc = time.time()
print '花费时间 %fs' % (toc - tic)
# Out:
# 迭代次数 0 / 3500: loss 782.356882
# 迭代次数 500 / 3500: loss 7.018716
# 迭代次数 1000 / 3500: loss 1.930007
# 迭代次数 1500 / 3500: loss 1.900960
# 迭代次数 2000 / 3500: loss 1.889138
# 迭代次数 2500 / 3500: loss 1.904636
# 迭代次数 3000 / 3500: loss 1.929516
# 花费时间 16.398000s

# %%
# 查看损失值的变化情况
plt.plot(loss_hist)
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %%
# 测试训练集，验证集的精度
y_train_pred = softmax.predict(X_sample)
print y_train_pred.shape
print '训练数据量：%f    训练正确率: %f' % (X_sample.shape[0],np.mean(y_sample == y_train_pred), )
y_val_pred = softmax.predict(X_val)
print '验证数据量：%f    验证正确率: %f' % (X_val.shape[0],np.mean(y_val == y_val_pred), )
# Out:
# (250L,)
# 训练数据量：250.000000    训练正确率: 0.544000
# 验证数据量：100.000000    验证正确率: 0.230000

# %% [markdown]
# ## 5.使用验证数据选择超参数

# %%
#使用验证集调整超参数(权重衰减因子，学习率)
from classifiers.chapter2.softmax import *
results = {}
best_val = -1
best_l = 0
best_r = 0
best_softmax = None
learning_rates=np.logspace(-9, 0, num=10)
regularization_strengths=np.logspace(0, 5, num=10)
batch_size = [50]
num_iters  = [300]

for b in batch_size:
    for n in num_iters:
        for l in learning_rates:
            for r in regularization_strengths:
                 softmax = Softmax()
                 loss_hist = softmax.train(X_sample, y_sample, 
                                           learning_rate=l,reg=r,
                                           num_iters=n,
                                           batch_size=b,
                                           verbose=False)
                 y_train_pred = softmax.predict(X_sample)
                 train_accuracy= np.mean(y_sample == y_train_pred)
                 y_val_pred = softmax.predict(X_val)
                 val_accuracy= np.mean(y_val == y_val_pred)
                 results[(l,r)]=(train_accuracy,val_accuracy)
                 if (best_val < val_accuracy):
                    best_val = val_accuracy
                    best_softmax = softmax
                    best_l =l
                    best_r =r
    
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e 训练精度: %f 验证精度: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print '最佳学习率为：%e 最佳权重衰减系数为：%e 其所对应的验证精度为: %f' % (best_l,best_r,best_val)
# Out:
# lr 1.000000e-09 reg 1.000000e+00 训练精度: 0.096000 验证精度: 0.070000
# lr 1.000000e-09 reg 3.593814e+00 训练精度: 0.124000 验证精度: 0.070000
# lr 1.000000e-09 reg 1.291550e+01 训练精度: 0.092000 验证精度: 0.110000
# lr 1.000000e-09 reg 4.641589e+01 训练精度: 0.116000 验证精度: 0.090000
# lr 1.000000e-09 reg 1.668101e+02 训练精度: 0.112000 验证精度: 0.140000
# lr 1.000000e-09 reg 5.994843e+02 训练精度: 0.092000 验证精度: 0.130000
# lr 1.000000e-09 reg 2.154435e+03 训练精度: 0.088000 验证精度: 0.120000
# lr 1.000000e-09 reg 7.742637e+03 训练精度: 0.120000 验证精度: 0.070000
# lr 1.000000e-09 reg 2.782559e+04 训练精度: 0.084000 验证精度: 0.120000
# lr 1.000000e-09 reg 1.000000e+05 训练精度: 0.128000 验证精度: 0.150000
# lr 1.000000e-08 reg 1.000000e+00 训练精度: 0.156000 验证精度: 0.160000
# lr 1.000000e-08 reg 3.593814e+00 训练精度: 0.128000 验证精度: 0.110000
# lr 1.000000e-08 reg 1.291550e+01 训练精度: 0.128000 验证精度: 0.130000
# lr 1.000000e-08 reg 4.641589e+01 训练精度: 0.144000 验证精度: 0.120000
# lr 1.000000e-08 reg 1.668101e+02 训练精度: 0.084000 验证精度: 0.110000
# lr 1.000000e-08 reg 5.994843e+02 训练精度: 0.108000 验证精度: 0.120000
# lr 1.000000e-08 reg 2.154435e+03 训练精度: 0.120000 验证精度: 0.050000
# lr 1.000000e-08 reg 7.742637e+03 训练精度: 0.120000 验证精度: 0.140000
# lr 1.000000e-08 reg 2.782559e+04 训练精度: 0.136000 验证精度: 0.140000
# lr 1.000000e-08 reg 1.000000e+05 训练精度: 0.120000 验证精度: 0.130000
# lr 1.000000e-07 reg 1.000000e+00 训练精度: 0.288000 验证精度: 0.140000
# lr 1.000000e-07 reg 3.593814e+00 训练精度: 0.288000 验证精度: 0.110000
# lr 1.000000e-07 reg 1.291550e+01 训练精度: 0.212000 验证精度: 0.100000
# lr 1.000000e-07 reg 4.641589e+01 训练精度: 0.264000 验证精度: 0.140000
# lr 1.000000e-07 reg 1.668101e+02 训练精度: 0.268000 验证精度: 0.160000
# lr 1.000000e-07 reg 5.994843e+02 训练精度: 0.248000 验证精度: 0.120000
# lr 1.000000e-07 reg 2.154435e+03 训练精度: 0.300000 验证精度: 0.150000
# lr 1.000000e-07 reg 7.742637e+03 训练精度: 0.292000 验证精度: 0.200000
# lr 1.000000e-07 reg 2.782559e+04 训练精度: 0.372000 验证精度: 0.260000
# lr 1.000000e-07 reg 1.000000e+05 训练精度: 0.448000 验证精度: 0.210000
# lr 1.000000e-06 reg 1.000000e+00 训练精度: 0.856000 验证精度: 0.240000
# lr 1.000000e-06 reg 3.593814e+00 训练精度: 0.844000 验证精度: 0.210000
# lr 1.000000e-06 reg 1.291550e+01 训练精度: 0.868000 验证精度: 0.200000
# lr 1.000000e-06 reg 4.641589e+01 训练精度: 0.860000 验证精度: 0.180000
# lr 1.000000e-06 reg 1.668101e+02 训练精度: 0.836000 验证精度: 0.190000
# lr 1.000000e-06 reg 5.994843e+02 训练精度: 0.876000 验证精度: 0.160000
# lr 1.000000e-06 reg 2.154435e+03 训练精度: 0.880000 验证精度: 0.240000
# lr 1.000000e-06 reg 7.742637e+03 训练精度: 0.848000 验证精度: 0.260000
# lr 1.000000e-06 reg 2.782559e+04 训练精度: 0.580000 验证精度: 0.200000
# lr 1.000000e-06 reg 1.000000e+05 训练精度: 0.456000 验证精度: 0.240000
# lr 1.000000e-05 reg 1.000000e+00 训练精度: 1.000000 验证精度: 0.240000
# lr 1.000000e-05 reg 3.593814e+00 训练精度: 1.000000 验证精度: 0.200000
# lr 1.000000e-05 reg 1.291550e+01 训练精度: 1.000000 验证精度: 0.180000
# lr 1.000000e-05 reg 4.641589e+01 训练精度: 1.000000 验证精度: 0.250000
# lr 1.000000e-05 reg 1.668101e+02 训练精度: 1.000000 验证精度: 0.230000
# lr 1.000000e-05 reg 5.994843e+02 训练精度: 0.992000 验证精度: 0.240000
# lr 1.000000e-05 reg 2.154435e+03 训练精度: 0.748000 验证精度: 0.200000
# lr 1.000000e-05 reg 7.742637e+03 训练精度: 0.420000 验证精度: 0.230000
# lr 1.000000e-05 reg 2.782559e+04 训练精度: 0.276000 验证精度: 0.180000
# lr 1.000000e-05 reg 1.000000e+05 训练精度: 0.148000 验证精度: 0.190000
# lr 1.000000e-04 reg 1.000000e+00 训练精度: 1.000000 验证精度: 0.240000
# lr 1.000000e-04 reg 3.593814e+00 训练精度: 1.000000 验证精度: 0.150000
# lr 1.000000e-04 reg 1.291550e+01 训练精度: 1.000000 验证精度: 0.160000
# lr 1.000000e-04 reg 4.641589e+01 训练精度: 1.000000 验证精度: 0.210000
# lr 1.000000e-04 reg 1.668101e+02 训练精度: 0.500000 验证精度: 0.140000
# lr 1.000000e-04 reg 5.994843e+02 训练精度: 0.432000 验证精度: 0.190000
# lr 1.000000e-04 reg 2.154435e+03 训练精度: 0.216000 验证精度: 0.160000
# lr 1.000000e-04 reg 7.742637e+03 训练精度: 0.132000 验证精度: 0.100000
# lr 1.000000e-04 reg 2.782559e+04 训练精度: 0.064000 验证精度: 0.070000
# lr 1.000000e-04 reg 1.000000e+05 训练精度: 0.044000 验证精度: 0.080000
# lr 1.000000e-03 reg 1.000000e+00 训练精度: 1.000000 验证精度: 0.230000
# lr 1.000000e-03 reg 3.593814e+00 训练精度: 1.000000 验证精度: 0.230000
# lr 1.000000e-03 reg 1.291550e+01 训练精度: 0.656000 验证精度: 0.260000
# lr 1.000000e-03 reg 4.641589e+01 训练精度: 0.428000 验证精度: 0.120000
# lr 1.000000e-03 reg 1.668101e+02 训练精度: 0.308000 验证精度: 0.140000
# lr 1.000000e-03 reg 5.994843e+02 训练精度: 0.148000 验证精度: 0.080000
# lr 1.000000e-03 reg 2.154435e+03 训练精度: 0.076000 验证精度: 0.060000
# lr 1.000000e-03 reg 7.742637e+03 训练精度: 0.084000 验证精度: 0.080000
# lr 1.000000e-03 reg 2.782559e+04 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e-03 reg 1.000000e+05 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e-02 reg 1.000000e+00 训练精度: 0.792000 验证精度: 0.180000
# lr 1.000000e-02 reg 3.593814e+00 训练精度: 0.452000 验证精度: 0.190000
# lr 1.000000e-02 reg 1.291550e+01 训练精度: 0.336000 验证精度: 0.150000
# lr 1.000000e-02 reg 4.641589e+01 训练精度: 0.192000 验证精度: 0.100000
# lr 1.000000e-02 reg 1.668101e+02 训练精度: 0.132000 验证精度: 0.120000
# lr 1.000000e-02 reg 5.994843e+02 训练精度: 0.064000 验证精度: 0.080000
# lr 1.000000e-02 reg 2.154435e+03 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e-02 reg 7.742637e+03 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e-02 reg 2.782559e+04 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e-02 reg 1.000000e+05 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e-01 reg 1.000000e+00 训练精度: 0.384000 验证精度: 0.170000
# lr 1.000000e-01 reg 3.593814e+00 训练精度: 0.264000 验证精度: 0.100000
# lr 1.000000e-01 reg 1.291550e+01 训练精度: 0.072000 验证精度: 0.030000
# lr 1.000000e-01 reg 4.641589e+01 训练精度: 0.036000 验证精度: 0.050000
# lr 1.000000e-01 reg 1.668101e+02 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e-01 reg 5.994843e+02 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e-01 reg 2.154435e+03 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e-01 reg 7.742637e+03 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e-01 reg 2.782559e+04 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e-01 reg 1.000000e+05 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e+00 reg 1.000000e+00 训练精度: 0.092000 验证精度: 0.130000
# lr 1.000000e+00 reg 3.593814e+00 训练精度: 0.104000 验证精度: 0.070000
# lr 1.000000e+00 reg 1.291550e+01 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e+00 reg 4.641589e+01 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e+00 reg 1.668101e+02 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e+00 reg 5.994843e+02 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e+00 reg 2.154435e+03 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e+00 reg 7.742637e+03 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e+00 reg 2.782559e+04 训练精度: 0.116000 验证精度: 0.070000
# lr 1.000000e+00 reg 1.000000e+05 训练精度: 0.116000 验证精度: 0.070000
# 最佳学习率为：1.000000e-07 最佳权重衰减系数为：2.782559e+04 其所对应的验证精度为: 0.260000

# %%
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# 绘制训练数据精度
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

#绘制验证数据精度
colors = [results[x][1] for x in results] 
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
#使用验证集调整超参数(权重衰减因子，学习率)
from classifiers.chapter2.softmax import *
results = {}
best_val = -1
best_l = 0
best_r = 0
best_softmax = None
learning_rates=np.logspace(-6, -4, num=10)
regularization_strengths=np.logspace(-1, 4, num=5)
batch_size = [50]
num_iters  = [300]

for b in batch_size:
    for n in num_iters:
        for l in learning_rates:
            for r in regularization_strengths:
                 softmax = Softmax()
                 loss_hist = softmax.train(X_sample, y_sample,
                                           learning_rate=l, reg=r,
                                           num_iters=n,batch_size=b, verbose=False)
                 y_train_pred = softmax.predict(X_sample)
                 train_accuracy= np.mean(y_sample == y_train_pred)
                 y_val_pred = softmax.predict(X_val)
                 val_accuracy= np.mean(y_val == y_val_pred)
                 results[(l,r)]=(train_accuracy,val_accuracy)
                 if (best_val < val_accuracy):
                    best_val = val_accuracy
                    best_softmax = softmax
                    best_l =l
                    best_r =r

    
print '最佳学习率为：%e 最佳权重衰减系数为：%e 其所对应的验证精度为: %f' % (best_l,best_r,best_val)
# Out:
# 最佳学习率为：1.668101e-06 最佳权重衰减系数为：3.162278e+01 其所对应的验证精度为: 0.280000

# %%
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]


# 绘制训练数据精度
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

#绘制验证数据精度
colors = [results[x][1] for x in results] 
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
#使用验证集调整超参数(权重衰减因子，学习率)
from classifiers.chapter2.softmax import *
results = {}
best_val = -1
best_l = 0
best_r = 0
best_softmax = None
learning_rates=np.logspace(-5, -4, num=10)
regularization_strengths=np.logspace(-2, 3, num=5)
batch_size = [50]
num_iters  = [300]

for b in batch_size:
    for n in num_iters:
        for l in learning_rates:
            for r in regularization_strengths:
                 softmax = Softmax()
                 loss_hist = softmax.train(X_sample, y_sample, learning_rate=l,
                                           reg=r,num_iters=n,batch_size=b, verbose=False)
                 y_train_pred = softmax.predict(X_sample)
                 train_accuracy= np.mean(y_sample == y_train_pred)
                 y_val_pred = softmax.predict(X_val)
                 val_accuracy= np.mean(y_val == y_val_pred)
                 results[(l,r)]=(train_accuracy,val_accuracy)
                 if (best_val < val_accuracy):
                    best_val = val_accuracy
                    best_softmax = softmax
                    best_l =l
                    best_r =r

    
print '最佳学习率为：%e 最佳权重衰减系数为：%e 其所对应的验证精度为: %f' % (best_l,best_r,best_val)
# Out:
# 最佳学习率为：3.593814e-05 最佳权重衰减系数为：1.000000e+03 其所对应的验证精度为: 0.280000

# %%
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')


colors = [results[x][1] for x in results] 
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
#在测试数据集上评估最佳softmax分类器
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print '测试集精度: %f' % test_accuracy
# Out:
# 测试集精度: 0.247400

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=10000):
  cifar10_dir = 'datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir) 
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]  
  X_train = np.reshape(X_train, (X_train.shape[0], -1))
  X_val = np.reshape(X_val, (X_val.shape[0], -1))
  X_test = np.reshape(X_test, (X_test.shape[0], -1))  
  mean_image = np.mean(X_train, axis = 0)
  X_train -= mean_image
  X_val -= mean_image
  X_test -= mean_image
  X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
  X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
  X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))]) 
  return X_train, y_train, X_val, y_val, X_test, y_test


X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
# Out:
# Train data shape:  (49000L, 3073L)
# Train labels shape:  (49000L,)
# Validation data shape:  (1000L, 3073L)
# Validation labels shape:  (1000L,)
# Test data shape:  (10000L, 3073L)
# Test labels shape:  (10000L,)

# %%
from classifiers.chapter2.softmax  import Softmax
results = {}
best_val = -1
best_softmax = None
################################################################################
#                            任务:                                             #
#               使用全部训练数据训练一个最佳softmax                            #
################################################################################
learning_rates = [1.4e-7, 1.45e-7, 1.5e-7, 1.55e-7, 1.6e-7]
regularization_strengths = [2.3e4, 2.6e4, 2.7e4, 2.8e4, 2.9e4]
for l in learning_rates:
    for r in regularization_strengths:
        softmax = Softmax()
        loss_hist = softmax.train(X_train, y_train, learning_rate=l, 
                                  reg=r,num_iters=2000, verbose=True)
        y_train_pred = softmax.predict(X_train)
        train_accuracy= np.mean(y_train == y_train_pred)
        y_val_pred = softmax.predict(X_val)
        val_accuracy= np.mean(y_val == y_val_pred)
        results[(l,r)]=(train_accuracy,val_accuracy)
        if (best_val < val_accuracy):
            best_val = val_accuracy
            best_softmax = softmax
################################################################################
#                            结束编码                                          #
################################################################################

for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print '最佳验证精度为: %f' % best_val
# Out:
# 迭代次数 0 / 2000: loss 357.871033
# 迭代次数 500 / 2000: loss 15.924552
# 迭代次数 1000 / 2000: loss 2.634430
# 迭代次数 1500 / 2000: loss 1.988431
# 迭代次数 0 / 2000: loss 401.631792
# 迭代次数 500 / 2000: loss 12.239370
# 迭代次数 1000 / 2000: loss 2.290267
# 迭代次数 1500 / 2000: loss 2.035056
# 迭代次数 0 / 2000: loss 423.322293
# 迭代次数 500 / 2000: loss 11.445179
# 迭代次数 1000 / 2000: loss 2.170652
# 迭代次数 1500 / 2000: loss 2.107942
# 迭代次数 0 / 2000: loss 439.640170
# 迭代次数 500 / 2000: loss 10.453247
# 迭代次数 1000 / 2000: loss 2.179406
# 迭代次数 1500 / 2000: loss 2.026219
# 迭代次数 0 / 2000: loss 454.048958
# 迭代次数 500 / 2000: loss 9.700909
# 迭代次数 1000 / 2000: loss 2.153128
# 迭代次数 1500 / 2000: loss 1.994040
# 迭代次数 0 / 2000: loss 360.113519
# 迭代次数 500 / 2000: loss 14.381442
# 迭代次数 1000 / 2000: loss 2.359497
# 迭代次数 1500 / 2000: loss 2.035796
# 迭代次数 0 / 2000: loss 405.841165
# 迭代次数 500 / 2000: loss 11.058998
# 迭代次数 1000 / 2000: loss 2.207977
# 迭代次数 1500 / 2000: loss 2.059043
# 迭代次数 0 / 2000: loss 423.029437
# 迭代次数 500 / 2000: loss 10.206967
# 迭代次数 1000 / 2000: loss 2.164329
# 迭代次数 1500 / 2000: loss 2.053581
# 迭代次数 0 / 2000: loss 442.227902
# 迭代次数 500 / 2000: loss 9.417581
# 迭代次数 1000 / 2000: loss 2.125818
# 迭代次数 1500 / 2000: loss 2.116458
# 迭代次数 0 / 2000: loss 451.329544
# 迭代次数 500 / 2000: loss 8.545935
# 迭代次数 1000 / 2000: loss 2.143877
# 迭代次数 1500 / 2000: loss 2.042445
# 迭代次数 0 / 2000: loss 364.774420
# 迭代次数 500 / 2000: loss 13.177017
# 迭代次数 1000 / 2000: loss 2.359565
# 迭代次数 1500 / 2000: loss 2.037077
# 迭代次数 0 / 2000: loss 405.412999
# 迭代次数 500 / 2000: loss 9.897373
# 迭代次数 1000 / 2000: loss 2.233033
# 迭代次数 1500 / 2000: loss 1.954329
# 迭代次数 0 / 2000: loss 418.723767
# 迭代次数 500 / 2000: loss 9.136645
# 迭代次数 1000 / 2000: loss 2.116235
# 迭代次数 1500 / 2000: loss 1.974881
# 迭代次数 0 / 2000: loss 430.865199
# 迭代次数 500 / 2000: loss 8.278471
# 迭代次数 1000 / 2000: loss 2.141678
# 迭代次数 1500 / 2000: loss 2.093781
# 迭代次数 0 / 2000: loss 454.130099
# 迭代次数 500 / 2000: loss 7.642684
# 迭代次数 1000 / 2000: loss 2.117935
# 迭代次数 1500 / 2000: loss 1.988636
# 迭代次数 0 / 2000: loss 360.787709
# 迭代次数 500 / 2000: loss 11.920948
# 迭代次数 1000 / 2000: loss 2.272150
# 迭代次数 1500 / 2000: loss 2.011261
# 迭代次数 0 / 2000: loss 408.561413
# 迭代次数 500 / 2000: loss 8.981411
# 迭代次数 1000 / 2000: loss 2.196896
# 迭代次数 1500 / 2000: loss 2.025191
# 迭代次数 0 / 2000: loss 416.352364
# 迭代次数 500 / 2000: loss 8.162130
# 迭代次数 1000 / 2000: loss 2.106724
# 迭代次数 1500 / 2000: loss 2.021870
# 迭代次数 0 / 2000: loss 441.016316
# 迭代次数 500 / 2000: loss 7.648536
# 迭代次数 1000 / 2000: loss 2.081747
# 迭代次数 1500 / 2000: loss 2.055768
# 迭代次数 0 / 2000: loss 444.458369
# 迭代次数 500 / 2000: loss 6.818855
# 迭代次数 1000 / 2000: loss 2.078097
# 迭代次数 1500 / 2000: loss 2.044798
# 迭代次数 0 / 2000: loss 354.011066
# 迭代次数 500 / 2000: loss 10.622999
# 迭代次数 1000 / 2000: loss 2.244274
# 迭代次数 1500 / 2000: loss 1.987462
# 迭代次数 0 / 2000: loss 406.692725
# 迭代次数 500 / 2000: loss 8.055784
# 迭代次数 1000 / 2000: loss 2.155760
# 迭代次数 1500 / 2000: loss 2.034407
# 迭代次数 0 / 2000: loss 413.840402
# 迭代次数 500 / 2000: loss 7.321875
# 迭代次数 1000 / 2000: loss 2.141164
# 迭代次数 1500 / 2000: loss 2.017909
# 迭代次数 0 / 2000: loss 437.098866
# 迭代次数 500 / 2000: loss 6.737289
# 迭代次数 1000 / 2000: loss 2.056674
# 迭代次数 1500 / 2000: loss 2.067196
# 迭代次数 0 / 2000: loss 452.759071
# 迭代次数 500 / 2000: loss 6.242610
# 迭代次数 1000 / 2000: loss 2.063844
# 迭代次数 1500 / 2000: loss 2.061289
# lr 1.400000e-07 reg 2.300000e+04 train accuracy: 0.357857 val accuracy: 0.374000
# lr 1.400000e-07 reg 2.600000e+04 train accuracy: 0.353592 val accuracy: 0.370000
# lr 1.400000e-07 reg 2.700000e+04 train accuracy: 0.348449 val accuracy: 0.357000
# lr 1.400000e-07 reg 2.800000e+04 train accuracy: 0.342878 val accuracy: 0.352000
# lr 1.400000e-07 reg 2.900000e+04 train accuracy: 0.344061 val accuracy: 0.362000
# lr 1.450000e-07 reg 2.300000e+04 train accuracy: 0.350163 val accuracy: 0.361000
# lr 1.450000e-07 reg 2.600000e+04 train accuracy: 0.354449 val accuracy: 0.372000
# lr 1.450000e-07 reg 2.700000e+04 train accuracy: 0.350755 val accuracy: 0.370000
# lr 1.450000e-07 reg 2.800000e+04 train accuracy: 0.346551 val accuracy: 0.355000
# lr 1.450000e-07 reg 2.900000e+04 train accuracy: 0.346163 val accuracy: 0.354000
# lr 1.500000e-07 reg 2.300000e+04 train accuracy: 0.352204 val accuracy: 0.370000
# lr 1.500000e-07 reg 2.600000e+04 train accuracy: 0.348245 val accuracy: 0.359000
# lr 1.500000e-07 reg 2.700000e+04 train accuracy: 0.349245 val accuracy: 0.369000
# lr 1.500000e-07 reg 2.800000e+04 train accuracy: 0.347612 val accuracy: 0.362000
# lr 1.500000e-07 reg 2.900000e+04 train accuracy: 0.348918 val accuracy: 0.364000
# lr 1.550000e-07 reg 2.300000e+04 train accuracy: 0.354857 val accuracy: 0.363000
# lr 1.550000e-07 reg 2.600000e+04 train accuracy: 0.346306 val accuracy: 0.359000
# lr 1.550000e-07 reg 2.700000e+04 train accuracy: 0.350408 val accuracy: 0.362000
# lr 1.550000e-07 reg 2.800000e+04 train accuracy: 0.344143 val accuracy: 0.359000
# lr 1.550000e-07 reg 2.900000e+04 train accuracy: 0.347490 val accuracy: 0.365000
# lr 1.600000e-07 reg 2.300000e+04 train accuracy: 0.354776 val accuracy: 0.363000
# lr 1.600000e-07 reg 2.600000e+04 train accuracy: 0.343082 val accuracy: 0.360000
# lr 1.600000e-07 reg 2.700000e+04 train accuracy: 0.352286 val accuracy: 0.363000
# lr 1.600000e-07 reg 2.800000e+04 train accuracy: 0.347082 val accuracy: 0.359000
# lr 1.600000e-07 reg 2.900000e+04 train accuracy: 0.345673 val accuracy: 0.359000
# 最佳验证精度为: 0.374000

# %%
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print '测试集精度: %f' % test_accuracy
# Out:
# 测试集精度: 0.358500

# %%
# 可视化学习到的参数
w = best_softmax.W[:-1,:] # 移除偏置项
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in xrange(10):
  plt.subplot(2, 5, i + 1)
  #将权重缩放回0-255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])
